# %%
using JLD2
data=load_object("data_jld2.jld");
orders_dict = data.data_dict["orders_dict"]

# for a in orders_dict
#     println(a)
# end
# Out:
# ┌ Warning: type Main.DataMod.Data does not exist in workspace; reconstructing
# └ @ JLD2 C:\Users\DALab\.julia\packages\JLD2\fAkkN\src\data\reconstructing_datatypes.jl:450
# ┌ Warning: type Main.DataMod.DataTransform.MachineGroupMod.MachineGroup does not exist in workspace; interpreting Array{Main.DataMod.DataTransform.MachineGroupMod.MachineGroup} as Array{Any}
# └ @ JLD2 C:\Users\DALab\.julia\packages\JLD2\fAkkN\src\datasets.jl:196
# ┌ Warning: type Main.DataMod.DataTransform.MachineGroupMod.MachineGroup does not exist in workspace; reconstructing
# └ @ JLD2 C:\Users\DALab\.julia\packages\JLD2\fAkkN\src\data\reconstructing_datatypes.jl:450
# ┌ Warning: type Main.DataMod.DataTransform.MachineMod.Machine does not exist in workspace; reconstructing
# └ @ JLD2 C:\Users\DALab\.julia\packages\JLD2\fAkkN\src\data\reconstructing_datatypes.jl:450
# ┌ Warning: type Main.DataMod.DataTransform.MachineMod.LoadingMod.Bucket does not exist in workspace; reconstructing
# ...

# %%
using Pkg
Pkg.add("JLD2")
# Out:
#     Fetching: [========================================>]  99.9 %========>                                ]  17.5 %Fetching: [=========>                               ]  21.1 %>                          ]  34.3 %>         ]  76.9 %Fetching: [==================================>      ]  83.9 %> ]  97.2 %
